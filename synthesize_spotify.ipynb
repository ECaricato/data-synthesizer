# %%
from sdv.sampling import Condition
from sdv.lite import SingleTablePreset
from sdv.datasets.local import load_csvs
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import get_column_plot

# %%
datasets = load_csvs(".")
real_data = datasets["spotify_tracks"]

metadata = SingleTableMetadata()
metadata.detect_from_dataframe(real_data)
# Out:
# C:\Users\emanu\PycharmProjects\data-synthesizer\venv\lib\site-packages\sdv\datasets\local.py:31: UserWarning: Ignoring incompatible files ['.gitignore', 'synth.py', 'synthesize.py', 'synthesize_spotify.ipynb', 'test.ipynb', 'test_data.py', 'trained_generated_model.h5'] in folder '.'.
#   warnings.warn(

# %%
synthesizer = SingleTablePreset(
    metadata=metadata,
    name='FAST_ML'
)

# %%
synthesizer.fit(real_data)

# %%
# create list of all unique track_genres in real_data
track_genres = real_data['track_genre'].unique().tolist()

# %%
# sample 1000 rows per genre
conditions = [
    Condition(num_rows=1000, column_values={'track_genre': genre})
    for genre in track_genres
]

synthetic_data = synthesizer.sample_from_conditions(conditions=conditions, output_file_path='synthetic_data.csv')
# Out:
# Sampling conditions: 100%|██████████| 114000/114000 [00:34<00:00, 3290.28it/s]

# %%
synthetic_data.head()
# Out:
#    Unnamed: 0                track_id            artists  \
# 0        1001  7IikbYJuxnILUaytiJ6KXY  Girls' Generation
# 1         778  6S3JlDAGk3uu3NtZbPnuhS           Megadeth
# 2         519  6S3JlDAGk3uu3NtZbPnuhS    Özdemir Erdoğan
# 3         550  0iAkkPHwTkS1nC2vbcw3Ms      Kishore Kumar
# 4         449  5W1UtLcQLQOFZDpDeNn8Gi    Bobby Goldsboro
#
#                                         album_name  \
# 0                             Fragments of Freedom
# 1                            This Is Jimmy Clanton
# 2                      Return of the Dream Canteen
# 3  Panakkaran (Original Motion Picture Soundtrack)
# 4                         Super Fun Learning Songs
#
#                                           track_name  popularity  duration_ms  \
# 0                                     Snap Out Of It          40       223551
# 1                                       Posso Clamar          44       303386
# 2                                    Run Rudolph Run          61       104428
# 3                                 The Wilhelm Scream          14       203147
# 4  12 Variations on an Allegretto in B Flat, K.50...          42       168044
#
#    explicit  danceability    energy  ...   loudness  mode  speechiness  \
# 0     False      0.140962  0.308925  ... -12.935391     0     0.000000
# 1     False      0.648285  0.739773  ...  -3.925941     1     0.000000
# 2      True      0.456375  0.243728  ... -15.601375     1     0.080802
# 3      True      0.472842  0.850369  ...  -4.642574     0     0.211355
# 4     False      0.209686  0.553700  ...  -6.717145     0     0.000000
#
#    acousticness  instrumentalness  liveness   valence       tempo  \
# 0      0.829654          0.085631  0.320180  0.099219   58.253383
# 1      0.167758          0.510550  0.106409  0.322010  117.675969
# 2      0.716644          0.126997  0.082134  0.000000   75.465353
# 3      0.000000          0.316360  0.456496  0.168052  132.867038
# 4      0.338755          0.000000  0.430138  0.000000   97.643418
#
#    time_signature  track_genre
# 0               3     acoustic
# 1               3     acoustic
# 2               4     acoustic
# 3               4     acoustic
# 4               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# quality_report = evaluate_quality(
#     real_data,
#     synthetic_data,
#     metadata
# )

# %%
fig = get_column_plot(
    real_data=real_data,
    synthetic_data=synthetic_data,
    column_name='tempo',
    metadata=metadata
)
    
fig.show()
# Out:
# <div>                            <div id="db21ce92-de76-4d21-b2e4-8b655ec02341" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("