# %%
# %pip install sdv
# Out:
# Collecting sdv
#   Obtaining dependency information for sdv from https://files.pythonhosted.org/packages/bf/dc/584e1a86cb553fe4eb58cc04c35af7d37063491e670cc3b5872b8475afc2/sdv-1.4.0-py2.py3-none-any.whl.metadata
#   Downloading sdv-1.4.0-py2.py3-none-any.whl.metadata (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 2.9 MB/s eta 0:00:00
# Collecting boto3<2,>=1.15.0 (from sdv)
#   Obtaining dependency information for boto3<2,>=1.15.0 from https://files.pythonhosted.org/packages/4d/65/a0927694bb02d8ae46c399d9a8ed2cd9c724adbc9bbb7849a0650850ad31/boto3-1.28.61-py3-none-any.whl.metadata
#   Downloading boto3-1.28.61-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<2,>=1.18 (from sdv)
#   Obtaining dependency information for botocore<2,>=1.18 from https://files.pythonhosted.org/packages/3b/6b/5292877865d820007c2c1afde587f17a2815e3e16d1a28421486f2816d81/botocore-1.31.61-py3-none-any.whl.metadata
#   Downloading botocore-1.31.61-py3-none-any.whl.metadata (6.0 kB)
# Collecting cloudpickle<3.0,>=2.1.0 (from sdv)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting Faker<15,>=10 (from sdv)
#   Downloading Faker-14.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.9 MB/s eta 0:00:00:00:01
# Collecting graphviz<1,>=0.13.2 (from sdv)
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.7 MB/s eta 0:00:00
# Collecting tqdm<5,>=4.15 (from sdv)
#   Obtaining dependency information for tqdm<5,>=4.15 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.7 MB/s eta 0:00:00
# Collecting copulas<0.10,>=0.9.0 (from sdv)
#   Obtaining dependency information for copulas<0.10,>=0.9.0 from https://files.pythonhosted.org/packages/be/b5/cb0f3f96f760366dfba5d66376af0a9b34cf06b364cb722ef3b8cf2a40e1/copulas-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading copulas-0.9.1-py2.py3-none-any.whl.metadata (20 kB)
# Collecting ctgan<0.8,>=0.7.4 (from sdv)
#   Obtaining dependency information for ctgan<0.8,>=0.7.4 from https://files.pythonhosted.org/packages/cc/ad/577a9c231b7b40115bd252b260eca05ec1ce8e3a2299e462b39bf74c0265/ctgan-0.7.5-py2.py3-none-any.whl.metadata
#   Downloading ctgan-0.7.5-py2.py3-none-any.whl.metadata (21 kB)
# Collecting deepecho<0.5,>=0.4.2 (from sdv)
#   Obtaining dependency information for deepecho<0.5,>=0.4.2 from https://files.pythonhosted.org/packages/1f/69/55334c9ed0cf494c6fdc38cedca7a3a589962e0c488406d138e616b00c59/deepecho-0.4.2-py2.py3-none-any.whl.metadata
#   Downloading deepecho-0.4.2-py2.py3-none-any.whl.metadata (15 kB)
# Collecting rdt<2,>=1.7.0 (from sdv)
#   Obtaining dependency information for rdt<2,>=1.7.0 from https://files.pythonhosted.org/packages/24/2e/f4f711401c4f53baa57122428a253522da2327b06df378341de6329a23bb/rdt-1.7.0-py2.py3-none-any.whl.metadata
#   Downloading rdt-1.7.0-py2.py3-none-any.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 1.7 MB/s eta 0:00:00
# Collecting sdmetrics<0.12,>=0.11.0 (from sdv)
#   Obtaining dependency information for sdmetrics<0.12,>=0.11.0 from https://files.pythonhosted.org/packages/d4/f8/d9670479ba93556a31afaa0ffc430d62b9e9c83dd2c9de09b279f640caae/sdmetrics-0.11.1-py2.py3-none-any.whl.metadata
#   Downloading sdmetrics-0.11.1-py2.py3-none-any.whl.metadata (35 kB)
# Collecting numpy<1.25.0,>=1.23.3 (from sdv)
#   Obtaining dependency information for numpy<1.25.0,>=1.23.3 from https://files.pythonhosted.org/packages/10/be/ae5bf4737cb79ba437879915791f6f26d92583c738d7d960ad94e5c36adf/numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: pandas>=1.3.4 in /home/codespace/.local/lib/python3.10/site-packages (from sdv) (2.1.1)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.15.0->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3<2,>=1.15.0->sdv)
#   Obtaining dependency information for s3transfer<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/5a/4b/fec9ce18f8874a96c5061422625ba86c3ee1e6587ccd92ff9f5bf7bd91b2/s3transfer-0.7.0-py3-none-any.whl.metadata
#   Downloading s3transfer-0.7.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/codespace/.local/lib/python3.10/site-packages (from botocore<2,>=1.18->sdv) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<2,>=1.18->sdv)
#   Obtaining dependency information for urllib3<1.27,>=1.25.4 from https://files.pythonhosted.org/packages/48/fe/a5c6cc46e9fe9171d7ecf0f33ee7aae14642f8d74baa7af4d7840f9358be/urllib3-1.26.17-py2.py3-none-any.whl.metadata
#   Downloading urllib3-1.26.17-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4,>=3.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from copulas<0.10,>=0.9.0->sdv) (3.8.0)
# Requirement already satisfied: scipy<2,>=1.9.2 in /home/codespace/.local/lib/python3.10/site-packages (from copulas<0.10,>=0.9.0->sdv) (1.11.3)
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /home/codespace/.local/lib/python3.10/site-packages (from ctgan<0.8,>=0.7.4->sdv) (1.3.1)
# Requirement already satisfied: torch>=1.11.0 in /home/codespace/.local/lib/python3.10/site-packages (from ctgan<0.8,>=0.7.4->sdv) (2.0.1)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.3.4->sdv) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.3.4->sdv) (2023.3)
# Requirement already satisfied: psutil<6,>=5.7 in /home/codespace/.local/lib/python3.10/site-packages (from rdt<2,>=1.7.0->sdv) (5.9.5)
# Requirement already satisfied: plotly<6,>=5.10.0 in /home/codespace/.local/lib/python3.10/site-packages (from sdmetrics<0.12,>=0.11.0->sdv) (5.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from plotly<6,>=5.10.0->sdmetrics<0.12,>=0.11.0->sdv) (8.2.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.18->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn<2,>=1.1.3->ctgan<0.8,>=0.7.4->sdv) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn<2,>=1.1.3->ctgan<0.8,>=0.7.4->sdv) (3.2.0)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.12.4)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (4.8.0)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (1.12)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.1)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.8/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (68.0.0)
# Requirement already satisfied: wheel in /home/codespace/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (0.41.2)
# Requirement already satisfied: cmake in /home/codespace/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.27.5)
# Requirement already satisfied: lit in /home/codespace/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (17.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/codespace/.local/lib/python3.10/site-packages (from sympy->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (1.3.0)
# Downloading sdv-1.4.0-py2.py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 4.2 MB/s eta 0:00:00
# Downloading boto3-1.28.61-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 4.9 MB/s eta 0:00:00
# Downloading botocore-1.31.61-py3-none-any.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 49.2 MB/s eta 0:00:00:00:010:01
# Downloading copulas-0.9.1-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 1.9 MB/s eta 0:00:00
# Downloading ctgan-0.7.5-py2.py3-none-any.whl (27 kB)
# Downloading deepecho-0.4.2-py2.py3-none-any.whl (29 kB)
# Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 48.8 MB/s eta 0:00:00:00:0100:01
# Downloading rdt-1.7.0-py2.py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 2.7 MB/s eta 0:00:00
# Downloading sdmetrics-0.11.1-py2.py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 6.3 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 3.2 MB/s eta 0:00:00
# Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 2.6 MB/s eta 0:00:00
# Downloading urllib3-1.26.17-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: urllib3, tqdm, numpy, jmespath, graphviz, cloudpickle, Faker, botocore, s3transfer, rdt, copulas, boto3, sdmetrics, deepecho, ctgan, sdv
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.5
#     Uninstalling urllib3-2.0.5:
#       Successfully uninstalled urllib3-2.0.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.0
#     Uninstalling numpy-1.26.0:
#       Successfully uninstalled numpy-1.26.0
# Successfully installed Faker-14.2.1 boto3-1.28.61 botocore-1.31.61 cloudpickle-2.2.1 copulas-0.9.1 ctgan-0.7.5 deepecho-0.4.2 graphviz-0.20.1 jmespath-1.0.1 numpy-1.24.4 rdt-1.7.0 s3transfer-0.7.0 sdmetrics-0.11.1 sdv-1.4.0 tqdm-4.66.1 urllib3-1.26.17
# Note: you may need to restart the kernel to use updated packages.

# %%
from sdv.sampling import Condition
from sdv.lite import SingleTablePreset
from sdv.datasets.local import load_csvs
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import get_column_plot

# %%
datasets = load_csvs(".")
real_data = datasets["spotify_tracks_reduced"]

metadata = SingleTableMetadata()
metadata.detect_from_dataframe(real_data)
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/sdv/datasets/local.py:31: UserWarning: Ignoring incompatible files ['synthesize_spotify.ipynb', 'README.md', 'synth.py', '.gitignore'] in folder '.'.
#   warnings.warn(

# %%
synthesizer = SingleTablePreset(
    metadata=metadata,
    name='FAST_ML'
)

# %%
synthesizer.fit(real_data)

# %%
# create list of all unique track_genres in real_data
track_genres = real_data['track_genre'].unique().tolist()

# %%
# sample 1000 rows per genre
conditions = [
    Condition(num_rows=1000, column_values={'track_genre': genre})
    for genre in track_genres
]

synthetic_data = synthesizer.sample_from_conditions(conditions=conditions, output_file_path='synthetic_data.csv')
# Out:
# Sampling conditions:   0%|          | 0/37000 [00:00<?, ?it/s]
# Sampling conditions: 100%|██████████| 37000/37000 [00:08<00:00, 4566.74it/s]

# %%
synthetic_data.head()
# Out:
#    Unnamed: 0                track_id            artists  \
# 0         624  5y0nMZC5kF6uLYaLc97mSo              Cream
# 1         573  4LfryUF6KUoJNPoOhSsV7z           Slipknot
# 2         164  4cO3Woi163T6kfaUEjsSFU  Eastmountainsouth
# 3         190  6KAf1Y6OHR34qdmgUFO5zf  my little airport
# 4         422  0XHkGVCs5hxW2gtHnPHkJi        Frei Gilson
#
#                       album_name          track_name  popularity  duration_ms  \
# 0                    在動物園散步才是正經事           Last Last          46       350550
# 1  die sometime, it's good for u              Places          74       160563
# 2             Gold-Diggers Sound      10,000 DOLLARS          40       304184
# 3            La Fine dell'Estate         Feels Right           1       221366
# 4    Mozart: A Night of Classics  Better Than Heaven          31       408802
#
#    explicit  danceability    energy  ...   loudness  mode  speechiness  \
# 0     False      0.425629  0.265287  ... -16.143084     1     0.082919
# 1      True      0.590011  0.599355  ...  -3.301788     1     0.153442
# 2     False      0.387066  0.827122  ... -10.761001     1     0.267515
# 3     False      0.656337  0.502719  ... -11.144860     1     0.002993
# 4     False      0.624698  0.178146  ... -19.895502     1     0.000000
#
#    acousticness  instrumentalness  liveness   valence       tempo  \
# 0      0.582338          0.352354  0.129548  0.381069  138.005954
# 1      0.346510          0.000000  0.514882  0.384911  104.775458
# 2      0.600324          0.508648  0.412060  0.452385  122.224720
# 3      0.184809          0.000000  0.011200  0.995000   79.907066
# 4      0.639736          0.625501  0.052142  0.323888  101.331384
#
#    time_signature  track_genre
# 0               4     acoustic
# 1               4     acoustic
# 2               3     acoustic
# 3               4     acoustic
# 4               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# quality_report = evaluate_quality(
#     real_data,
#     synthetic_data,
#     metadata
# )

# %%
fig = get_column_plot(
    real_data=real_data,
    synthetic_data=synthetic_data,
    column_name='acousticness',
    metadata=metadata
)
    
fig.show()
# Out:
# <div>                            <div id="2348c2bf-add7-49db-a3a4-30efe7af79ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2348c2bf-add7-49db-a3a4-30efe7af79ee")) {                    Plotly.newPlot(                        "2348c2bf-add7-49db-a3a4-30efe7af79ee",                        [{"legendgroup":"Real","marker":{"color":"#000036"},"mode":"lines","name":"Real","showlegend":true,"x":[0.0,0.001992,0.003984,0.005976,0.007968,0.00996,0.011952,0.013944,0.015936,0.017928,0.01992,0.021911999999999997,0.023904,0.025896000000000002,0.027888,0.02988,0.031872,0.033864,0.035856,0.037848,0.03984,0.041832,0.043823999999999995,0.045816,0.047808,0.0498,0.051792000000000005,0.053784,0.055776,0.057768,0.05976,0.061752,0.063744,0.065736,0.067728,0.06972,0.071712,0.07370399999999999,0.075696,0.07768800000000001